# %%
# Activate automatic reloading of modules in Jupyter Notebook
# %load_ext autoreload
# %autoreload 2

# %%
# Number of Games Created by Day
from src.plots.games_created_by_day import plot_games_created_by_day
plot_games_created_by_day()
